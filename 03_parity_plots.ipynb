# %% [markdown]
# # Generate Parity Plots for Operator Results
# Code author: Sahar H. El Abbadi
# Date started: 2023-02-23
# Date last edited: 2023-02-27

# %% [markdown]
# # Load Data
#
# ### Operator Data
# Load operator data cleaned in 02_data_cleaning.ipynb
#
# ### Metering Data
# - Data generated by Philippine Burdeau on 2023-02-23
# - Includes metered flow data, in kgh
# - Includes flow rates are calculated based on timestamps provided by operators and timestamps as determined by Stanford based on overpass time. Will need to determine which value to use for consistency

# %%
# Setup

# Imports
from plot_methods import plot_parity
from methods_data_cleaning import load_clean_operator_reports, load_meter_data

# Load clean operator data
# format for naming: [operator]_stage

cm_1, cm_2, cm_3, ghg_1, ghg_2, kairos_1_ls23, kairos_1_ls25, kairos_2_ls23, kairos_2_ls25, kairos_3_ls23, kairos_3_ls25 = load_clean_operator_reports()

# Load meter data
# cm_meter = metered data for Carbon Mapper overpasses
# ghg_meter = metered data for GHGSat overpasses
# kairos_meter = metered data for Kairos overpasses

cm_meter, ghg_meter, kairos_meter, mair_meter = load_meter_data('flightradar')

# %%
# Carbon Mapper Stage 1

# Info for plotting
operator = 'Carbon Mapper'
stage = 1

# Make parity plot
# plot_parity function filters for valid overpasses using Stanford's QC criteria
plot_parity(operator, stage, cm_1, cm_meter, strict_discard=False)

# %%
# Carbon Mapper Stage 2

# Info for plotting
operator = 'Carbon Mapper'
stage = 2

# Make parity plot
plot_parity(operator, stage, cm_2, cm_meter, strict_discard=False)

# %%
# Carbon Mapper Stage 3

# Info for plotting
operator = 'Carbon Mapper'
stage = 3

# Make parity plot
# plot_parity function filters for valid overpasses using Stanford's QC criteria
plot_parity(operator, stage, cm_1, cm_meter, strict_discard=False)

# %%
# GHGSat Stage 1

# Info for plotting
operator = 'GHGSat'
stage = 1

# Make parity plot
plot_parity(operator, stage, ghg_1, ghg_meter, strict_discard=False)

# %%
# GHGSat Stage 2

# Info for plotting
operator = 'GHGSat'
stage = 2

# Make parity plot
plot_parity(operator, stage, ghg_2, ghg_meter, strict_discard=False)

# %%
# Kairos LS23 Stage 1

# Info for plotting
operator = 'Kairos LS23'
stage = 1

# Make parity plot
plot_parity(operator, stage, kairos_1_ls23, kairos_meter, strict_discard=False)

# %%
# Kairos LS25 Stage 1

# Info for plotting
operator = 'Kairos LS25'
stage = 1

# Make parity plot
plot_parity(operator, stage, kairos_1_ls25, kairos_meter, strict_discard=False)

# %%
# Kairos LS23 Stage 2

# Info for plotting
operator = 'Kairos LS23'
stage = 2

# Make parity plot
plot_parity(operator, stage, kairos_2_ls23, kairos_meter, strict_discard=False)

# %%
# Kairos LS25 Stage 2

# Info for plotting
operator = 'Kairos LS25'
stage = 2

# Make parity plot
plot_parity(operator, stage, kairos_2_ls25, kairos_meter, strict_discard=False)

# %%
# Kairos LS23 Stage 3

# Info for plotting
operator = 'Kairos LS23'
stage = 3

# Make parity plot
plot_parity(operator, stage, kairos_3_ls23, kairos_meter, strict_discard=False)

# %%
# Kairos LS25 Stage 3

# Info for plotting
operator = 'Kairos LS25'
stage = 3

# Make parity plot
plot_parity(operator, stage, kairos_3_ls25, kairos_meter, strict_discard=False)

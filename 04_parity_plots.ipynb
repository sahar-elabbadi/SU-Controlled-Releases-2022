# %% [markdown]
# # Generate Parity Plots for Operator Results
# Code author: Sahar H. El Abbadi
# Date started: 2023-02-23
# Date last edited: 2023-02-27

# %% [markdown]
# # Load Data
#
# ### Operator Data
# Load operator data cleaned in 02_data_cleaning.ipynb
#
# ### Metering Data
# - Data generated by Philippine Burdeau on 2023-02-23
# - Includes metered flow data, in kgh
# - Includes flow rates are calculated based on timestamps provided by operators and timestamps as determined by Stanford based on overpass time. Will need to determine which value to use for consistency

# %%
# Setup

# Imports
from plot_methods import plot_parity

# %%
# Carbon Mapper Stage 1
from plot_methods import plot_parity
# Info for plotting
operator = 'Carbon Mapper'
stage = 1

# Make parity plot
# plot_parity function filters for valid overpasses using Stanford's QC criteria
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Carbon Mapper Stage 2

# Info for plotting
operator = 'Carbon Mapper'
stage = 2

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Carbon Mapper Stage 3

# Info for plotting
operator = 'Carbon Mapper'
stage = 3

# Make parity plot
# plot_parity function filters for valid overpasses using Stanford's QC criteria
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# GHGSat Stage 1
from plot_methods import plot_parity
# Info for plotting
operator = 'GHGSat'
stage = 1

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# GHGSat Stage 2

# Info for plotting
operator = 'GHGSat'
stage = 2

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# GHGSat Stage 3

# Info for plotting
operator = 'GHGSat'
stage = 3

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos Combo Stage 1

# Info for plotting
operator = 'Kairos'
stage = 1

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos Combo Stage 2

# Info for plotting
operator = 'Kairos'
stage = 2

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos Combo Stage 3

# Info for plotting
operator = 'Kairos'
stage = 3

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Scientific Aviation
from plot_methods import plot_parity

# Info for plotting
operator = 'Scientific Aviation'
stage = 1

# Make parity plot - lax SU criteria includes Overpass #5 with trailer change mid-way through release causing a jump in flow rate
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Scientific Aviation
from plot_methods import plot_parity

# Info for plotting
operator = 'Scientific Aviation'
stage = 1

# Make parity plot - lax SU criteria includes Overpass #5 with trailer change mid-way through release causing a jump in flow rate
plot_parity(operator, stage, strict_discard=True, time_ave=60, gas_comp_source='km')

# %%
# Methane Air
from plot_methods import plot_parity

# Info for plotting
operator = 'Methane Air'
stage = 1

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos LS23 Stage 1

# Info for plotting
operator = 'Kairos LS23'
stage = 1

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos LS25 Stage 1

# Info for plotting
operator = 'Kairos LS25'
stage = 1

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos LS23 Stage 2

# Info for plotting
operator = 'Kairos LS23'
stage = 2

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos LS25 Stage 2

# Info for plotting
operator = 'Kairos LS25'
stage = 2

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos LS23 Stage 3

# Info for plotting
operator = 'Kairos LS23'
stage = 3

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos LS25 Stage 3

# Info for plotting
operator = 'Kairos LS25'
stage = 3

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Methane Air mIME
from plot_methods import plot_parity

# Info for plotting
operator = 'MethaneAIR mIME'
stage = 1

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Methane Air DI
from plot_methods import plot_parity

# Info for plotting
operator = 'MethaneAIR DI'
stage = 1

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

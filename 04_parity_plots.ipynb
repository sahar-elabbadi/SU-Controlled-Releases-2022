# %% [markdown]
# # Generate Parity Plots for Operator Results
# Code author: Sahar H. El Abbadi
# Date started: 2023-02-23
# Date last edited: 2023-02-27

# %% [markdown]
# # Load Data
#
# ### Operator Data
# Load operator data cleaned in 02_data_cleaning.ipynb
#
# ### Metering Data
# - Data generated by Philippine Burdeau on 2023-02-23
# - Includes metered flow data, in kgh
# - Includes flow rates are calculated based on timestamps provided by operators and timestamps as determined by Stanford based on overpass time. Will need to determine which value to use for consistency

# %%
# Setup

# Imports
from plot_methods import plot_parity

# %%
# Carbon Mapper Stage 1
from plot_methods import plot_parity
# Info for plotting
operator = 'Carbon Mapper'
stage = 1

# Make parity plot
# plot_parity function filters for valid overpasses using Stanford's QC criteria
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Carbon Mapper Stage 2

# Info for plotting
operator = 'Carbon Mapper'
stage = 2

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Carbon Mapper Stage 3

# Info for plotting
operator = 'Carbon Mapper'
stage = 3

# Make parity plot
# plot_parity function filters for valid overpasses using Stanford's QC criteria
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# GHGSat Stage 1
from plot_methods import plot_parity
# Info for plotting
operator = 'GHGSat'
stage = 1

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# GHGSat Stage 2

# Info for plotting
operator = 'GHGSat'
stage = 2

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# GHGSat Stage 3

# Info for plotting
operator = 'GHGSat'
stage = 3

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos Combo Stage 1

# Info for plotting
operator = 'Kairos'
stage = 1

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos Combo Stage 2

# Info for plotting
operator = 'Kairos'
stage = 2

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos Combo Stage 3

# Info for plotting
operator = 'Kairos'
stage = 3

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Scientific Aviation
from plot_methods import plot_parity

# Info for plotting
operator = 'Scientific Aviation'
stage = 1

# Make parity plot - lax SU criteria includes Overpass #5 with trailer change mid-way through release causing a jump in flow rate
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Scientific Aviation
from plot_methods import plot_parity

# Info for plotting
operator = 'Scientific Aviation'
stage = 1

# Make parity plot - lax SU criteria includes Overpass #5 with trailer change mid-way through release causing a jump in flow rate
plot_parity(operator, stage, strict_discard=True, time_ave=60, gas_comp_source='km')

# %%
# Methane Air
from plot_methods import plot_parity

# Info for plotting
operator = 'Methane Air'
stage = 1

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos LS23 Stage 1

# Info for plotting
operator = 'Kairos LS23'
stage = 1

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[14], line 8
#       5 stage = 1
#       7 # Make parity plot
# ----> 8 plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')
#
# File ~/PycharmProjects/CRF22_Airplanes/plot_methods.py:109, in plot_parity(operator, stage, strict_discard, time_ave, gas_comp_source)
#     105 # Add x = y line
#     106 plt.plot(x_seq, x_seq, color='k', lw=2, linestyle='--',
#     107          label='y = x')
# --> 109 ax.errorbar(x_data, y_data,
#     110             xerr=x_error,
#     111             yerr=y_error,
#     112             linestyle='none',
#     113             mfc='white',
#     114             label=f'{operator} Stage {stage} data',
#     115             fmt='o',
#     116             markersize=5)
#     118 # Set title
#     119 plt.title(f'{operator} Stage {stage} Results ({sample_size} measurements)')
#
# File ~/PycharmProjects/CRF22_Airplanes/venv/lib/python3.10/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/PycharmProjects/CRF22_Airplanes/venv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:3534, in Axes.errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3532     xerr = _upcast_err(xerr)
#    3533 if yerr is not None and not isinstance(yerr, np.ndarray):
# -> 3534     yerr = _upcast_err(yerr)
#    3535 x, y = np.atleast_1d(x, y)  # Make sure all the args are iterable.
#    3536 if len(x) != len(y):
#
# File ~/PycharmProjects/CRF22_Airplanes/venv/lib/python3.10/site-packages/matplotlib/axes/_axes.py:3516, in Axes.errorbar.<locals>._upcast_err(err)
#    3492 def _upcast_err(err):
#    3493     """
#    3494     Safely handle tuple of containers that carry units.
#    3495
#    (...)
#    3504     Otherwise, fallback to casting to an object array.
#    3505     """
#    3507     if (
#    3508             # make sure it is not a scalar
#    3509             np.iterable(err) and
#    3510             # and it is not empty
#    3511             len(err) > 0 and
#    3512             # and the first element is an array sub-class use
#    3513             # safe_first_element because getitem is index-first not
#    3514             # location first on pandas objects so err[0] almost always
#    3515             # fails.
# -> 3516             isinstance(cbook._safe_first_finite(err), np.ndarray)
#    3517     ):
#    3518         # Get the type of the first element
#    3519         atype = type(cbook._safe_first_finite(err))
#    3520         # Promote the outer container to match the inner container
#
# File ~/PycharmProjects/CRF22_Airplanes/venv/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1715, in _safe_first_finite(obj, skip_nonfinite)
#    1712     raise RuntimeError("matplotlib does not "
#    1713                        "support generators as input")
#    1714 else:
# -> 1715     return next(val for val in obj if safe_isfinite(val))
#
# StopIteration:

# %%
# Kairos LS25 Stage 1

# Info for plotting
operator = 'Kairos LS25'
stage = 1

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos LS23 Stage 2

# Info for plotting
operator = 'Kairos LS23'
stage = 2

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos LS25 Stage 2

# Info for plotting
operator = 'Kairos LS25'
stage = 2

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos LS23 Stage 3

# Info for plotting
operator = 'Kairos LS23'
stage = 3

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Kairos LS25 Stage 3

# Info for plotting
operator = 'Kairos LS25'
stage = 3

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Methane Air mIME
from plot_methods import plot_parity

# Info for plotting
operator = 'MethaneAIR mIME'
stage = 1

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')

# %%
# Methane Air DI
from plot_methods import plot_parity

# Info for plotting
operator = 'MethaneAIR DI'
stage = 1

# Make parity plot
plot_parity(operator, stage, strict_discard=False, time_ave=60, gas_comp_source='km')
